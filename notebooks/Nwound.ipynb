# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sqlalchemy import create_engine
from hold import connection_string

# %%
engine = create_engine(f'{connection_string}', encoding='iso-8859-1', connect_args={'connect_timeout': 10})

# %%
gtdDF = pd.read_sql_table('global_terrorism', con= engine)

# %%
gtdDF
# Out:
#        iyear  imonth  iday       date    country_txt  \
# 0       2000       1     1 2000-01-01        Namibia
# 1       2000       1     1 2000-01-01        Namibia
# 2       2000       1     1 2000-01-01          India
# 3       2000       1     1 2000-01-01         Kosovo
# 4       2000       1     1 2000-01-01        Somalia
# 5       2000       1     1 2000-01-01          India
# 6       2000       1     1 2000-01-01         Kosovo
# 7       2000       1     1 2000-01-01         Turkey
# 8       2000       1     1 2000-01-01          Spain
# 9       2000       1     1 2000-01-01          Spain
# 10      2000       1     1 2000-01-01     Bangladesh
# 11      2000       1     1 2000-01-01     Bangladesh
# 12      2000       1     1 2000-01-01     Bangladesh
# 13      2000       1     1 2000-01-01     Bangladesh
# 14      2000       1     1 2000-01-01     Bangladesh
# 15      2000       1     1 2000-01-01     Bangladesh
# 16      2000       1     1 2000-01-01  United States
# 17      2000       1     2 2000-01-02        Germany
# 18      2000       1     2 2000-01-02        Algeria
# 19      2000       1     2 2000-01-02       Colombia
# 20      2000       1     2 2000-01-02       Colombia
# 21      2000       1     3 2000-01-03        Namibia
# 22      2000       1     3 2000-01-03          India
# 23      2000       1     3 2000-01-03         Greece
# 24      2000       1     3 2000-01-03        Algeria
# 25      2000       1     3 2000-01-03  United States
# 26      2000       1     3 2000-01-03  United States
# 27      2000       1     3 2000-01-03  United States
# 28      2000       1     3 2000-01-03          Yemen
# 29      2000       1     4 2000-01-04          Spain
# ...      ...     ...   ...        ...            ...
# 92670   2016      12    31 2016-12-31          Egypt
# 92671   2016      12    31 2016-12-31    Philippines
# 92672   2016      12    31 2016-12-31    Philippines
# 92673   2016      12    31 2016-12-31     Bangladesh
# 92674   2016      12    30 2016-12-30       Pakistan
# 92675   2016      12    31 2016-12-31   Saudi Arabia
# 92676   2016      12    31 2016-12-31    Afghanistan
# 92677   2016      12    31 2016-12-31        Burundi
# 92678   2016      12    31 2016-12-31       Pakistan
# 92679   2016      12    31 2016-12-31          India
# 92680   2016      12    31 2016-12-31    Afghanistan
# 92681   2016      12    31 2016-12-31    Afghanistan
# 92682   2016      12    31 2016-12-31        Nigeria
# 92683   2016      12    31 2016-12-31           Iraq
# 92684   2016      12    31 2016-12-31           Iraq
# 92685   2016      12    31 2016-12-31           Iraq
# 92686   2016      12    31 2016-12-31           Iraq
# 92687   2016      12    31 2016-12-31           Iraq
# 92688   2016      12    31 2016-12-31           Iraq
# 92689   2016      12    31 2016-12-31       Pakistan
# 92690   2016      12    31 2016-12-31    Afghanistan
# 92691   2016      12    31 2016-12-31    Afghanistan
# 92692   2016      12    31 2016-12-31    Afghanistan
# 92693   2016      12    31 2016-12-31    Afghanistan
# 92694   2016      12    30 2016-12-30    Afghanistan
# 92695   2016      12    31 2016-12-31    Afghanistan
# 92696   2016      12    31 2016-12-31          Niger
# 92697   2016      12    31 2016-12-31    Philippines
# 92698   2016      12    31 2016-12-31         Mexico
# 92699   2016      12    30 2016-12-30          Sudan
#
#                        region_txt           provstate                    city  \
# 0              Sub-Saharan Africa             Kavango                Muitjiku
# 1              Sub-Saharan Africa             Kavango                Muitjiku
# 2                      South Asia   Jammu and Kashmir                Udhampur
# 3                  Eastern Europe   Kosovo (Province)                    Peje
# 4              Sub-Saharan Africa            Banaadir               Mogadishu
# 5                      South Asia               Assam              Kakotibari
# 6                  Eastern Europe   Kosovo (Province)               Gorazhdec
# 7      Middle East & North Africa            Istanbul                Istanbul
# 8                  Western Europe      Basque Country               Galdacano
# 9                  Western Europe      Basque Country                Guernica
# 10                     South Asia          Chittagong              Chittagong
# 11                     South Asia          Chittagong              Chittagong
# 12                     South Asia          Chittagong              Chittagong
# 13                     South Asia          Chittagong              Chittagong
# 14                     South Asia          Chittagong              Chittagong
# 15                     South Asia          Chittagong              Chittagong
# 16                  North America            Michigan                  Mesick
# 17                 Western Europe           Thuringia                  Erfurt
# 18     Middle East & North Africa    Medea (Province)               El Omaria
# 19                  South America              Bogota                  Bogota
# 20                  South America           Antioquia                 Unknown
# 21             Sub-Saharan Africa             Caprivi          Katima Mulilio
# 22                     South Asia   Jammu and Kashmir                Srinagar
# 23                 Western Europe              Attica                  Athens
# 24     Middle East & North Africa   Tipasa (Province)                 Germain
# 25                  North America          California                Petaluma
# 26                  North America                Ohio              Cincinnati
# 27                  North America                Ohio              Cincinnati
# 28     Middle East & North Africa                Adan                    Aden
# 29                 Western Europe      Basque Country                 Durango
# ...                           ...                 ...                     ...
# 92670  Middle East & North Africa         North Sinai                   Arish
# 92671              Southeast Asia      North Cotabato               Nabalawag
# 92672              Southeast Asia         Maguindanao                   Elian
# 92673                  South Asia             Rangpur              Sundarganj
# 92674                  South Asia              Punjab                 Sahiwal
# 92675  Middle East & North Africa               Jazan                 Unknown
# 92676                  South Asia               Kabul                   Kabul
# 92677          Sub-Saharan Africa             Bubanza                 Muzinda
# 92678                  South Asia  Khyber Pakhtunkhwa                Peshawar
# 92679                  South Asia             Manipur                  Imphal
# 92680                  South Asia               Farah               Bagh Kafi
# 92681                  South Asia               Logar  Mohammad Agha district
# 92682          Sub-Saharan Africa               Borno               Maiduguri
# 92683  Middle East & North Africa             Saladin              Mutaybijah
# 92684  Middle East & North Africa             Baghdad                 Baghdad
# 92685  Middle East & North Africa             Baghdad                 Baghdad
# 92686  Middle East & North Africa             Baghdad                 Baghdad
# 92687  Middle East & North Africa             Baghdad                 Baghdad
# 92688  Middle East & North Africa             Baghdad                 Baghdad
# 92689                  South Asia  Khyber Pakhtunkhwa                Gajukhel
# 92690                  South Asia             Jawzjan                   Zoqum
# 92691                  South Asia             Jawzjan                 Jakdalk
# 92692                  South Asia             Jawzjan                Shirkhel
# 92693                  South Asia             Jawzjan                   Tofan
# 92694                  South Asia             Jawzjan       Mangajek district
# 92695                  South Asia             Helmand             Lashkar Gah
# 92696          Sub-Saharan Africa               Diffa                  Garoua
# 92697              Southeast Asia         Maguindanao                 Talitay
# 92698               North America           Chihuahua               Guachochi
# 92699          Sub-Saharan Africa      Central Darfur                 Nertiti
#
#        latitude  longitude   ...      claimmode_txt  \
# 0        -17.91      19.99   ...               None
# 1        -17.91      19.99   ...               None
# 2         32.93      75.14   ...               None
# 3         42.66      20.31   ...               None
# 4          2.11      45.39   ...               None
# 5         27.09      95.02   ...               None
# 6         42.64      20.37   ...               None
# 7         41.01      28.98   ...               None
# 8         43.23      -2.85   ...               None
# 9         43.32      -2.68   ...               None
# 10        22.35      91.81   ...               None
# 11        22.35      91.81   ...               None
# 12        22.35      91.83   ...               None
# 13        22.35      91.83   ...               None
# 14        22.35      91.83   ...               None
# 15        22.35      91.81   ...               None
# 16        44.41     -85.71   ...               None
# 17        50.97      11.02   ...               None
# 18        36.26       3.03   ...               None
# 19         4.60     -74.08   ...               None
# 20         7.20     -75.34   ...               None
# 21       -17.50      24.28   ...               None
# 22        34.08      74.80   ...               None
# 23        38.01      23.82   ...              Other
# 24        36.52       2.55   ...               None
# 25        38.23    -122.64   ...             Letter
# 26        39.10     -84.51   ...               None
# 27        39.10     -84.51   ...               None
# 28        12.79      44.98   ...               None
# 29        43.17      -2.63   ...               None
# ...         ...        ...   ...                ...
# 92670     31.13      33.80   ...               None
# 92671      7.06     124.51   ...               None
# 92672      6.96     124.47   ...               None
# 92673     25.56      89.52   ...               None
# 92674     30.66      73.11   ...               None
# 92675     16.89      42.57   ...     Personal claim
# 92676     34.53      69.08   ...               None
# 92677     -3.25      29.43   ...               None
# 92678     34.01      71.58   ...               None
# 92679     24.81      93.92   ...               None
# 92680     32.37      62.12   ...               None
# 92681     34.22      69.08   ...               None
# 92682     11.83      13.15   ...               None
# 92683     34.35      44.47   ...               None
# 92684     33.38      44.34   ...               None
# 92685     33.33      44.40   ...             E-mail
# 92686     33.33      44.40   ...             E-mail
# 92687     33.31      44.49   ...               None
# 92688     33.37      44.28   ...               None
# 92689     33.80      72.03   ...               None
# 92690     36.66      65.75   ...     Personal claim
# 92691     36.67      65.75   ...     Personal claim
# 92692     36.67      65.75   ...     Personal claim
# 92693     36.66      65.75   ...     Personal claim
# 92694     37.01      66.03   ...     Personal claim
# 92695     31.58      64.37   ...               None
# 92696     13.88      13.18   ...               None
# 92697      7.03     124.39   ...               None
# 92698     26.82    -107.07   ...               None
# 92699     12.96      24.04   ...               None
#
#                    weaptype1_txt                           weapsubtype1_txt  \
# 0                       Firearms                           Unknown Gun Type
# 1                       Firearms                           Unknown Gun Type
# 2                       Firearms                           Unknown Gun Type
# 3      Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 4                       Firearms                           Unknown Gun Type
# 5      Explosives/Bombs/Dynamite                                  Time Fuse
# 6                       Firearms                           Unknown Gun Type
# 7      Explosives/Bombs/Dynamite                       Other Explosive Type
# 8                     Incendiary                        Gasoline or Alcohol
# 9                     Incendiary                        Gasoline or Alcohol
# 10     Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 11     Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 12                      Firearms                           Unknown Gun Type
# 13     Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 14     Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 15     Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 16                    Incendiary                        Gasoline or Alcohol
# 17                    Incendiary               Molotov Cocktail/Petrol Bomb
# 18                         Melee                Knife or Other Sharp Object
# 19     Explosives/Bombs/Dynamite                       Other Explosive Type
# 20     Explosives/Bombs/Dynamite                               Dynamite/TNT
# 21                      Firearms                           Unknown Gun Type
# 22     Explosives/Bombs/Dynamite                                  Land Mine
# 23                    Incendiary                                 Arson/Fire
# 24                      Firearms                           Unknown Gun Type
# 25                    Incendiary                                 Arson/Fire
# 26     Explosives/Bombs/Dynamite                                Letter Bomb
# 27     Explosives/Bombs/Dynamite                                Letter Bomb
# 28     Explosives/Bombs/Dynamite                                    Vehicle
# 29                    Incendiary                        Gasoline or Alcohol
# ...                          ...                                        ...
# 92670  Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 92671                   Firearms                           Automatic Weapon
# 92672                   Firearms                           Unknown Gun Type
# 92673                   Firearms                                    Handgun
# 92674                   Firearms                           Unknown Gun Type
# 92675  Explosives/Bombs/Dynamite  Projectile (rockets, mortars, RPGs, etc.)
# 92676  Explosives/Bombs/Dynamite                                Sticky Bomb
# 92677  Explosives/Bombs/Dynamite                                    Grenade
# 92678                   Firearms                           Unknown Gun Type
# 92679  Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 92680                   Firearms                           Unknown Gun Type
# 92681                   Firearms                           Unknown Gun Type
# 92682  Explosives/Bombs/Dynamite    Suicide (carried bodily by human being)
# 92683                    Unknown                                       None
# 92684  Explosives/Bombs/Dynamite                                    Vehicle
# 92685  Explosives/Bombs/Dynamite    Suicide (carried bodily by human being)
# 92686  Explosives/Bombs/Dynamite    Suicide (carried bodily by human being)
# 92687  Explosives/Bombs/Dynamite                                    Vehicle
# 92688  Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 92689                   Firearms                           Unknown Gun Type
# 92690                    Unknown                                       None
# 92691                    Unknown                                       None
# 92692                    Unknown                                       None
# 92693                    Unknown                                       None
# 92694  Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 92695  Explosives/Bombs/Dynamite                                  Land Mine
# 92696                    Unknown                                       None
# 92697  Explosives/Bombs/Dynamite                     Unknown Explosive Type
# 92698                   Firearms                                    Handgun
# 92699                   Firearms                           Unknown Gun Type
#
#       weaptype2_txt               weapsubtype2_txt kidhijcountry ransom nkill  \
# 0              None                           None          None    NaN   0.0
# 1              None                           None          None    0.0   0.0
# 2              None                           None          None    NaN   1.0
# 3              None                           None          None    NaN   0.0
# 4              None                           None          None    NaN   6.0
# 5              None                           None          None    NaN   0.0
# 6              None                           None          None    NaN   0.0
# 7              None                           None          None    NaN   0.0
# 8              None                           None          None    NaN   0.0
# 9              None                           None          None    NaN   0.0
# 10             None                           None          None    NaN   0.0
# 11             None                           None          None    NaN   0.0
# 12             None                           None          None    NaN   0.0
# 13         Firearms               Unknown Gun Type          None    NaN   0.0
# 14             None                           None          None    NaN   0.0
# 15             None                           None          None    NaN   0.0
# 16             None                           None          None    0.0   0.0
# 17             None                           None          None    NaN   0.0
# 18       Incendiary                     Arson/Fire          None    0.0   5.0
# 19             None                           None          None    NaN   0.0
# 20             None                           None          None    NaN   0.0
# 21             None                           None          None    NaN   3.0
# 22             None                           None          None    NaN  18.0
# 23             None                           None          None    NaN   0.0
# 24             None                           None          None    NaN   6.0
# 25             None                           None          None    NaN   0.0
# 26             None                           None          None    0.0   0.0
# 27             None                           None          None    0.0   0.0
# 28             None                           None          None    NaN   0.0
# 29             None                           None          None    NaN   0.0
# ...             ...                            ...           ...    ...   ...
# 92670          None                           None          None    NaN   2.0
# 92671          None                           None          None    NaN   0.0
# 92672          None                           None          None    NaN   0.0
# 92673          None                           None          None    NaN   1.0
# 92674          None                           None          None    NaN   0.0
# 92675      Firearms  Rifle/Shotgun (non-automatic)          None    NaN   1.0
# 92676          None                           None          None    NaN   2.0
# 92677          None                           None          None    NaN   0.0
# 92678          None                           None          None    NaN   1.0
# 92679          None                           None          None    NaN   0.0
# 92680          None                           None          None    NaN   0.0
# 92681          None                           None          None    0.0   1.0
# 92682          None                           None          None    NaN   2.0
# 92683          None                           None          None    NaN   3.0
# 92684          None                           None          None    NaN   2.0
# 92685          None                           None          None    NaN  15.0
# 92686          None                           None          None    NaN  15.0
# 92687          None                           None          None    NaN   4.0
# 92688          None                           None          None    NaN   1.0
# 92689          None                           None          None    NaN   2.0
# 92690          None                           None          None    NaN   1.0
# 92691          None                           None          None    NaN   1.0
# 92692          None                           None          None    NaN   0.0
# 92693          None                           None          None    NaN   0.0
# 92694          None                           None          None    NaN   2.0
# 92695          None                           None          None    NaN   1.0
# 92696          None                           None          None    NaN  15.0
# 92697          None                           None          None    NaN   0.0
# 92698          None                           None          None    NaN   0.0
# 92699          None                           None          None    NaN   0.0
#
#       nwound   index1
# 0        7.0      1.0
# 1        7.0      2.0
# 2        2.0      3.0
# 3        1.0      4.0
# 4       10.0      5.0
# 5        0.0      7.0
# 6        0.0      8.0
# 7        0.0      9.0
# 8        1.0     10.0
# 9        0.0     11.0
# 10       2.0     16.0
# 11       1.0     18.0
# 12       1.0     19.0
# 13      30.0     21.0
# 14       0.0     25.0
# 15       0.0     26.0
# 16       0.0     27.0
# 17       0.0     29.0
# 18       0.0     30.0
# 19       0.0     31.0
# 20       0.0     32.0
# 21       4.0     33.0
# 22      30.0     35.0
# 23       0.0     36.0
# 24      14.0     38.0
# 25       0.0     39.0
# 26       0.0     40.0
# 27       0.0     41.0
# 28       0.0     42.0
# 29       0.0     43.0
# ...      ...      ...
# 92670    1.0  99770.0
# 92671    1.0  99771.0
# 92672    0.0  99772.0
# 92673    0.0  99773.0
# 92674    2.0  99774.0
# 92675    0.0  99775.0
# 92676    4.0  99776.0
# 92677    8.0  99777.0
# 92678    1.0  99778.0
# 92679    0.0  99779.0
# 92680    1.0  99780.0
# 92681    0.0  99781.0
# 92682    1.0  99782.0
# 92683    2.0  99783.0
# 92684    0.0  99784.0
# 92685   22.0  99785.0
# 92686   21.0  99786.0
# 92687    0.0  99787.0
# 92688    7.0  99788.0
# 92689    0.0  99790.0
# 92690    1.0  99791.0
# 92691    1.0  99792.0
# 92692    2.0  99793.0
# 92693    1.0  99794.0
# 92694    5.0  99795.0
# 92695    6.0  99796.0
# 92696    7.0  99797.0
# 92697    0.0  99798.0
# 92698    0.0  99800.0
# 92699    0.0  99801.0
#
# [92700 rows x 31 columns]

# %%
gtdDF['nwound'].sum()
# Out:
# 358362.0

# %%
woundDF = gtdDF['nwound'].groupby(gtdDF['iyear']).sum()
woundDF = woundDF.reset_index()
woundDF
# Out:
#     iyear   nwound
# 0    2000   5495.0
# 1    2001  20964.0
# 2    2002   7083.0
# 3    2003   7004.0
# 4    2004  11798.0
# 5    2005  12582.0
# 6    2006  15409.0
# 7    2007  22393.0
# 8    2008  18931.0
# 9    2009  19122.0
# 10   2010  15849.0
# 11   2011  14624.0
# 12   2012  25358.0
# 13   2013  37573.0
# 14   2014  40781.0
# 15   2015  43795.0
# 16   2016  39601.0

# %%
# Assign X (data) and y (target)

### BEGIN SOLUTION
X = woundDF['iyear'].values.reshape(-1,1)
y = woundDF['nwound'].values.reshape(-1, 1)
print(X.shape, y.shape)
### END SOLUTION
# Out:
# (17, 1) (17, 1)

# %%
# Plot the data

### BEGIN SOLUTION

plt.scatter(X, y)

### END SOLUTION

# %%
# Create the model and fit the model to the data

from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()

### END SOLUTION

# %%
# Fit the model to the data. 
# Note: This is the training step where you fit the line to the data.

### BEGIN SOLUTION

model.fit(X, y)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Print the coefficient and the intercept for the model

### BEGIN SOLUTION
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
### END SOLUTION
# Out:
# Weight coefficients:  [[2072.72794118]]
# y-axis intercept:  [-4140957.58823529]

# %%
# Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])

print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[2000]]
# Max X Value: [[2016]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max

### BEGIN SOLUTION
y_min = model.predict(x_min)
y_max = model.predict(x_max)
### END SOLUTION

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]

### BEGIN SOLUTION
plt.scatter(X, y, c='orange')
plt.plot([x_min[0], x_max[0],], [y_min[0], y_max[0]], c='green')
plt.title("Wounded from Terrorism By Year")
plt.savefig('../GTA/front_end/static/front_end/assets/nwound_by_year.png')
### END SOLUTION

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION
# Out:
# D:\Users\Jollibee\anaconda\Anaconda3\envs\Django\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION
# Out:
# D:\Users\Jollibee\anaconda\Anaconda3\envs\Django\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# D:\Users\Jollibee\anaconda\Anaconda3\envs\Django\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.8628102196666436, R2: 0.34544018372829055

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.8489709352057467, R2: 0.3559391779306964

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.8617226016092008, R2: 0.3462652911037324

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.8495073248890538, R2: 0.3555322528334355
